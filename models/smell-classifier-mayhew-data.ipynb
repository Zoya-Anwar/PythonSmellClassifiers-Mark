# %%
# !pip install bayesian-optimization
import pandas as pd
from xgboost import XGBClassifier, cv
from sklearn.model_selection import train_test_split, cross_validate, StratifiedKFold, RandomizedSearchCV, GridSearchCV, cross_val_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.compose import ColumnTransformer
from bayes_opt import BayesianOptimization
import numpy as np

SEED=0
# Out:
# Requirement already satisfied: bayesian-optimization in /home/zoya/anaconda3/lib/python3.8/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.9.0 in /home/zoya/anaconda3/lib/python3.8/site-packages (from bayesian-optimization) (1.24.1)
# Requirement already satisfied: scipy>=1.0.0 in /home/zoya/anaconda3/lib/python3.8/site-packages (from bayesian-optimization) (1.10.0)
# Requirement already satisfied: scikit-learn>=0.18.0 in /home/zoya/anaconda3/lib/python3.8/site-packages (from bayesian-optimization) (1.2.0)
# Requirement already satisfied: colorama>=0.4.6 in /home/zoya/anaconda3/lib/python3.8/site-packages (from bayesian-optimization) (0.4.6)
# Requirement already satisfied: joblib>=1.1.1 in /home/zoya/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/zoya/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (3.1.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Load the dataset
# - Load data from excel sheet
# - Set X (independent variables) and y (dependent variables)

# %%
data_path = './data/mayhew1.csv'
na_values=['na']
df = pd.read_csv(data_path)
# smiles =  np.loadtxt("./data/smiles.txt", dtype='str')
y=df['odor.class'] # labels, independent variables
y = y.replace(['Odor'], True)
y = y.replace(['Odorless'], False)
assigned = df['dataset.assigned']
df = df.drop(['odor.class.source', 'dataset.assigned', 'odor.class', 
              'transport.ML.odor.probability', 'many.feature.ML.odor.probability'], axis=1)
df = df.set_index('SMILES')
X = df
df
# Out:
#                                         boiling.point.experimental  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                     228.5
# CC(=O)OC1CC(CC=C1C)C(=C)C                                      NaN
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                     NaN
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                         NaN
# CC1=CCC(CC1)(O)C(C)C                                         209.0
# ...                                                            ...
# CC(=CCC(CO)C(=C)C)C                                            NaN
# CC1=CCC(CC1O)C(=C)C                                          228.0
# C=CC(=O)OCC1CCCO1                                              NaN
# CCCCCCCCCCCCOCC                                                NaN
# CC1=CCC(C1(C)C)CC=O                                            NaN
#
#                                         boiling.point.estimate.EPISuite  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                         224.23
# CC(=O)OC1CC(CC=C1C)C(=C)C                                        245.13
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                       262.43
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                           331.88
# CC1=CCC(CC1)(O)C(C)C                                             211.85
# ...                                                                 ...
# CC(=CCC(CO)C(=C)C)C                                              221.70
# CC1=CCC(CC1O)C(=C)C                                              230.02
# C=CC(=O)OCC1CCCO1                                                201.85
# CCCCCCCCCCCCOCC                                                  261.25
# CC1=CCC(C1(C)C)CC=O                                              207.99
#
#                                         boiling.point.estimate.Banks  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                  177.316328
# CC(=O)OC1CC(CC=C1C)C(=C)C                                 220.067558
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                231.359855
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                    265.346589
# CC1=CCC(CC1)(O)C(C)C                                      181.799762
# ...                                                              ...
# CC(=CCC(CO)C(=C)C)C                                       181.799762
# CC1=CCC(CC1O)C(=C)C                                       179.574801
# C=CC(=O)OCC1CCCO1                                         183.884293
# CCCCCCCCCCCCOCC                                           236.000644
# CC1=CCC(C1(C)C)CC=O                                       179.574801
#
#                                         boiling.point.estimate.Burnop  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                   211.376140
# CC(=O)OC1CC(CC=C1C)C(=C)C                                  267.379260
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                 283.769094
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                     354.216698
# CC1=CCC(CC1)(O)C(C)C                                       205.923187
# ...                                                               ...
# CC(=CCC(CO)C(=C)C)C                                        195.317301
# CC1=CCC(CC1O)C(=C)C                                        208.589955
# C=CC(=O)OCC1CCCO1                                           99.383370
# CCCCCCCCCCCCOCC                                            265.201861
# CC1=CCC(C1(C)C)CC=O                                         96.015338
#
#                                         boiling.point.best.available  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                      228.50
# CC(=O)OC1CC(CC=C1C)C(=C)C                                     245.13
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                    262.43
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                        331.88
# CC1=CCC(CC1)(O)C(C)C                                          209.00
# ...                                                              ...
# CC(=CCC(CO)C(=C)C)C                                           221.70
# CC1=CCC(CC1O)C(=C)C                                           228.00
# C=CC(=O)OCC1CCCO1                                             201.85
# CCCCCCCCCCCCOCC                                               261.25
# CC1=CCC(C1(C)C)CC=O                                           207.99
#
#                                         vapor.pressure.experimental  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                   0.103000
# CC(=O)OC1CC(CC=C1C)C(=C)C                                       NaN
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                      NaN
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                     0.000512
# CC1=CCC(CC1)(O)C(C)C                                            NaN
# ...                                                             ...
# CC(=CCC(CO)C(=C)C)C                                             NaN
# CC1=CCC(CC1O)C(=C)C                                             NaN
# C=CC(=O)OCC1CCCO1                                               NaN
# CCCCCCCCCCCCOCC                                                 NaN
# CC1=CCC(C1(C)C)CC=O                                             NaN
#
#                                         vapor.pressure.best.available      MW  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                     0.103000  150.24
# CC(=O)OC1CC(CC=C1C)C(=C)C                                    0.035300  194.30
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                   0.013900  208.33
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                       0.000512  258.44
# CC1=CCC(CC1)(O)C(C)C                                         0.042700  154.28
# ...                                                               ...     ...
# CC(=CCC(CO)C(=C)C)C                                          0.019500  154.28
# CC1=CCC(CC1O)C(=C)C                                          0.013200  152.26
# C=CC(=O)OCC1CCCO1                                            0.329000  156.20
# CCCCCCCCCCCCOCC                                              0.024800  214.44
# CC1=CCC(C1(C)C)CC=O                                          0.242000  152.26
#
#                                           AMW      Sv  ...  Psychotic.80  \
# SMILES                                                 ...
# CC1=CC[C@H](CC1=O)C(=C)C                6.010  14.402  ...             0
# CC(=O)OC1CC(CC=C1C)C(=C)C               6.072  18.171  ...             0
# CCC(=O)OC1CC(CC=C1C)C(=C)C              5.952  19.698  ...             0
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C  5.743  25.563  ...             0
# CC1=CCC(CC1)(O)C(C)C                    5.320  15.456  ...             0
# ...                                       ...     ...  ...           ...
# CC(=CCC(CO)C(=C)C)C                     5.320  15.456  ...             0
# CC1=CCC(CC1O)C(=C)C                     5.639  14.929  ...             0
# C=CC(=O)OCC1CCCO1                       6.791  13.305  ...             0
# CCCCCCCCCCCCOCC                         4.765  22.617  ...             0
# CC1=CCC(C1(C)C)CC=O                     5.639  14.929  ...             0
#
#                                         Psychotic.50  Hypertens.80  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                           0             0
# CC(=O)OC1CC(CC=C1C)C(=C)C                          0             0
# CCC(=O)OC1CC(CC=C1C)C(=C)C                         0             1
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C             0             0
# CC1=CCC(CC1)(O)C(C)C                               0             0
# ...                                              ...           ...
# CC(=CCC(CO)C(=C)C)C                                0             0
# CC1=CCC(CC1O)C(=C)C                                0             0
# C=CC(=O)OCC1CCCO1                                  0             0
# CCCCCCCCCCCCOCC                                    0             0
# CC1=CCC(C1(C)C)CC=O                                0             0
#
#                                         Hypertens.50  Hypnotic.80  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                           0            0
# CC(=O)OC1CC(CC=C1C)C(=C)C                          0            1
# CCC(=O)OC1CC(CC=C1C)C(=C)C                         0            1
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C             0            0
# CC1=CCC(CC1)(O)C(C)C                               0            0
# ...                                              ...          ...
# CC(=CCC(CO)C(=C)C)C                                0            0
# CC1=CCC(CC1O)C(=C)C                                0            0
# C=CC(=O)OCC1CCCO1                                  0            0
# CCCCCCCCCCCCOCC                                    0            0
# CC1=CCC(C1(C)C)CC=O                                0            0
#
#                                         Hypnotic.50  Neoplastic.80  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                          0              0
# CC(=O)OC1CC(CC=C1C)C(=C)C                         0              1
# CCC(=O)OC1CC(CC=C1C)C(=C)C                        0              1
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C            0              0
# CC1=CCC(CC1)(O)C(C)C                              0              0
# ...                                             ...            ...
# CC(=CCC(CO)C(=C)C)C                               0              0
# CC1=CCC(CC1O)C(=C)C                               0              0
# C=CC(=O)OCC1CCCO1                                 0              0
# CCCCCCCCCCCCOCC                                   0              0
# CC1=CCC(C1(C)C)CC=O                               0              0
#
#                                         Neoplastic.50  Infective.80  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                            0             1
# CC(=O)OC1CC(CC=C1C)C(=C)C                           0             1
# CCC(=O)OC1CC(CC=C1C)C(=C)C                          0             1
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C              0             1
# CC1=CCC(CC1)(O)C(C)C                                0             1
# ...                                               ...           ...
# CC(=CCC(CO)C(=C)C)C                                 0             1
# CC1=CCC(CC1O)C(=C)C                                 0             1
# C=CC(=O)OCC1CCCO1                                   0             0
# CCCCCCCCCCCCOCC                                     0             0
# CC1=CCC(C1(C)C)CC=O                                 0             0
#
#                                         Infective.50
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                           0
# CC(=O)OC1CC(CC=C1C)C(=C)C                          0
# CCC(=O)OC1CC(CC=C1C)C(=C)C                         0
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C             0
# CC1=CCC(CC1)(O)C(C)C                               0
# ...                                              ...
# CC(=CCC(CO)C(=C)C)C                                0
# CC1=CCC(CC1O)C(=C)C                                0
# C=CC(=O)OCC1CCCO1                                  0
# CCCCCCCCCCCCOCC                                    0
# CC1=CCC(C1(C)C)CC=O                                0
#
# [1924 rows x 4870 columns]

# %%
y
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1919    True
# 1920    True
# 1921    True
# 1922    True
# 1923    True
# Name: odor.class, Length: 1924, dtype: bool

# %% [markdown]
# # Split the dataset
# - Split dataset into training and test set
# - Use equal proportions of odor/odorless class

# %%
assigned
train = assigned == 'train'
X_train_t = df.iloc[list(train[train].index)]
y_train_t = y.iloc[list(train[train].index)]
X_train_t
# Out:
#                             boiling.point.experimental  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                         NaN
# CC1=CCC(CC1)(O)C(C)C                             209.0
# CC1=CC[C@](CC1)(O)C(C)C                          209.0
# O=C1C2(C)CCC(C1(C)C)C2                           193.0
# OCC1=CC[C@H](CC1)C(=C)C                          244.0
# ...                                                ...
# CC(=CCC(CO)C(=C)C)C                                NaN
# CC1=CCC(CC1O)C(=C)C                              228.0
# C=CC(=O)OCC1CCCO1                                  NaN
# CCCCCCCCCCCCOCC                                    NaN
# CC1=CCC(C1(C)C)CC=O                                NaN
#
#                             boiling.point.estimate.EPISuite  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                           262.43
# CC1=CCC(CC1)(O)C(C)C                                 211.85
# CC1=CC[C@](CC1)(O)C(C)C                              211.85
# O=C1C2(C)CCC(C1(C)C)C2                               203.89
# OCC1=CC[C@H](CC1)C(=C)C                              241.19
# ...                                                     ...
# CC(=CCC(CO)C(=C)C)C                                  221.70
# CC1=CCC(CC1O)C(=C)C                                  230.02
# C=CC(=O)OCC1CCCO1                                    201.85
# CCCCCCCCCCCCOCC                                      261.25
# CC1=CCC(C1(C)C)CC=O                                  207.99
#
#                             boiling.point.estimate.Banks  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                    231.359855
# CC1=CCC(CC1)(O)C(C)C                          181.799762
# CC1=CC[C@](CC1)(O)C(C)C                       181.799762
# O=C1C2(C)CCC(C1(C)C)C2                        179.574801
# OCC1=CC[C@H](CC1)C(=C)C                       179.574801
# ...                                                  ...
# CC(=CCC(CO)C(=C)C)C                           181.799762
# CC1=CCC(CC1O)C(=C)C                           179.574801
# C=CC(=O)OCC1CCCO1                             183.884293
# CCCCCCCCCCCCOCC                               236.000644
# CC1=CCC(C1(C)C)CC=O                           179.574801
#
#                             boiling.point.estimate.Burnop  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                     283.769094
# CC1=CCC(CC1)(O)C(C)C                           205.923187
# CC1=CC[C@](CC1)(O)C(C)C                        205.923187
# O=C1C2(C)CCC(C1(C)C)C2                         104.485216
# OCC1=CC[C@H](CC1)C(=C)C                        208.589955
# ...                                                   ...
# CC(=CCC(CO)C(=C)C)C                            195.317301
# CC1=CCC(CC1O)C(=C)C                            208.589955
# C=CC(=O)OCC1CCCO1                               99.383370
# CCCCCCCCCCCCOCC                                265.201861
# CC1=CCC(C1(C)C)CC=O                             96.015338
#
#                             boiling.point.best.available  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                        262.43
# CC1=CCC(CC1)(O)C(C)C                              209.00
# CC1=CC[C@](CC1)(O)C(C)C                           209.00
# O=C1C2(C)CCC(C1(C)C)C2                            193.00
# OCC1=CC[C@H](CC1)C(=C)C                           244.00
# ...                                                  ...
# CC(=CCC(CO)C(=C)C)C                               221.70
# CC1=CCC(CC1O)C(=C)C                               228.00
# C=CC(=O)OCC1CCCO1                                 201.85
# CCCCCCCCCCCCOCC                                   261.25
# CC1=CCC(C1(C)C)CC=O                               207.99
#
#                             vapor.pressure.experimental  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                          NaN
# CC1=CCC(CC1)(O)C(C)C                                NaN
# CC1=CC[C@](CC1)(O)C(C)C                             NaN
# O=C1C2(C)CCC(C1(C)C)C2                            0.817
# OCC1=CC[C@H](CC1)C(=C)C                             NaN
# ...                                                 ...
# CC(=CCC(CO)C(=C)C)C                                 NaN
# CC1=CCC(CC1O)C(=C)C                                 NaN
# C=CC(=O)OCC1CCCO1                                   NaN
# CCCCCCCCCCCCOCC                                     NaN
# CC1=CCC(C1(C)C)CC=O                                 NaN
#
#                             vapor.pressure.best.available      MW    AMW  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                        0.01390  208.33  5.952
# CC1=CCC(CC1)(O)C(C)C                              0.04270  154.28  5.320
# CC1=CC[C@](CC1)(O)C(C)C                           0.04270  154.28  5.320
# O=C1C2(C)CCC(C1(C)C)C2                            0.81700  152.26  5.639
# OCC1=CC[C@H](CC1)C(=C)C                           0.00478  152.26  5.639
# ...                                                   ...     ...    ...
# CC(=CCC(CO)C(=C)C)C                               0.01950  154.28  5.320
# CC1=CCC(CC1O)C(=C)C                               0.01320  152.26  5.639
# C=CC(=O)OCC1CCCO1                                 0.32900  156.20  6.791
# CCCCCCCCCCCCOCC                                   0.02480  214.44  4.765
# CC1=CCC(C1(C)C)CC=O                               0.24200  152.26  5.639
#
#                                 Sv  ...  Psychotic.80  Psychotic.50  \
# SMILES                              ...
# CCC(=O)OC1CC(CC=C1C)C(=C)C  19.698  ...             0             0
# CC1=CCC(CC1)(O)C(C)C        15.456  ...             0             0
# CC1=CC[C@](CC1)(O)C(C)C     15.456  ...             0             0
# O=C1C2(C)CCC(C1(C)C)C2      14.929  ...             0             0
# OCC1=CC[C@H](CC1)C(=C)C     14.929  ...             0             0
# ...                            ...  ...           ...           ...
# CC(=CCC(CO)C(=C)C)C         15.456  ...             0             0
# CC1=CCC(CC1O)C(=C)C         14.929  ...             0             0
# C=CC(=O)OCC1CCCO1           13.305  ...             0             0
# CCCCCCCCCCCCOCC             22.617  ...             0             0
# CC1=CCC(C1(C)C)CC=O         14.929  ...             0             0
#
#                             Hypertens.80  Hypertens.50  Hypnotic.80  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C             1             0            1
# CC1=CCC(CC1)(O)C(C)C                   0             0            0
# CC1=CC[C@](CC1)(O)C(C)C                0             0            0
# O=C1C2(C)CCC(C1(C)C)C2                 0             0            0
# OCC1=CC[C@H](CC1)C(=C)C                0             0            0
# ...                                  ...           ...          ...
# CC(=CCC(CO)C(=C)C)C                    0             0            0
# CC1=CCC(CC1O)C(=C)C                    0             0            0
# C=CC(=O)OCC1CCCO1                      0             0            0
# CCCCCCCCCCCCOCC                        0             0            0
# CC1=CCC(C1(C)C)CC=O                    0             0            0
#
#                             Hypnotic.50  Neoplastic.80  Neoplastic.50  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C            0              1              0
# CC1=CCC(CC1)(O)C(C)C                  0              0              0
# CC1=CC[C@](CC1)(O)C(C)C               0              0              0
# O=C1C2(C)CCC(C1(C)C)C2                0              0              0
# OCC1=CC[C@H](CC1)C(=C)C               0              0              0
# ...                                 ...            ...            ...
# CC(=CCC(CO)C(=C)C)C                   0              0              0
# CC1=CCC(CC1O)C(=C)C                   0              0              0
# C=CC(=O)OCC1CCCO1                     0              0              0
# CCCCCCCCCCCCOCC                       0              0              0
# CC1=CCC(C1(C)C)CC=O                   0              0              0
#
#                             Infective.80  Infective.50
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C             1             0
# CC1=CCC(CC1)(O)C(C)C                   1             0
# CC1=CC[C@](CC1)(O)C(C)C                1             0
# O=C1C2(C)CCC(C1(C)C)C2                 1             0
# OCC1=CC[C@H](CC1)C(=C)C                1             0
# ...                                  ...           ...
# CC(=CCC(CO)C(=C)C)C                    1             0
# CC1=CCC(CC1O)C(=C)C                    1             0
# C=CC(=O)OCC1CCCO1                      0             0
# CCCCCCCCCCCCOCC                        0             0
# CC1=CCC(C1(C)C)CC=O                    0             0
#
# [1864 rows x 4870 columns]

# %%
test = assigned == 'test'
X_test = df.iloc[list(test[test].index)]
y_test = y.iloc[list(test[test].index)]
X_test
# Out:
#                                                     boiling.point.experimental  \
# SMILES
# CCC(C)C1CCCCC1=O                                                           NaN
# C(CCC(=O)O)CC(=O)O                                                       337.5
# CCOC(=O)C1=CC=C(C=C1)N                                                   310.0
# OC[C@H]1O[C@@H]2O[C@@H]3[C@@H](CO)O[C@@H]([C@@H...                         NaN
# CC1=C(C(CCC1)(C)C)C=CC(=O)C                                                NaN
# CC1(C2CCC1(C(=O)C2)C)C                                                   204.0
# CC/C=C\CCOC(=O)C                                                           NaN
# CC1=C(C(=O)CC1)O                                                           NaN
# CC(=O)OC[C@]1(O[C@H]2O[C@@H](COC(=O)C)[C@@H]([C...                         NaN
# CCCCCC1CCCC(=O)O1                                                          NaN
# CSCSC                                                                    148.0
# CCCCCCCCCCCCCCC(=O)OCC                                                     NaN
# O=C1C=C[C@]2([C@H](N1)CC[C@@H]1[C@@H]2CC[C@]2([...                         NaN
# CC(=CCC/C(=C/CCC(=O)C)/C)C                                                 NaN
# COC(C(c1ccccc1)C)OC                                                        NaN
# CCCCCCCC(=O)OCCC(C)C                                                       NaN
# CC=Cc1ccc(c(c1)OC)OC(=O)Cc1ccccc1                                          NaN
# CC(C)CC(C(=O)O)N                                                           NaN
# CC(C)C(C(=O)O)N                                                            NaN
# CC1=C(C(=O)C=CO1)O                                                         NaN
# O=C1CC(C)C2(C(=C1)CCC(C2)C(=C)C)C                                          NaN
# C1=CC=C2C(=C1)C=CC3=CC=CC=C32                                            340.0
# C1=CC=C(C=C1)CCOC(=O)C2=CC=CC=C2                                           NaN
# CCC=O                                                                     48.0
# CCOC(=O)[C@@H](N[C@H](C(=O)N1[C@H]2CCC[C@H]2C[C...                         NaN
# C/C(=C\CC/C=C(/CC/C=C(/CCC=C(C)C)\C)\C)/CC/C=C(...                         NaN
# COc1cnc(nc1)NS(=O)(=O)c1ccc(cc1)N                                          NaN
# CCCCCCC=CC=CC=O                                                            NaN
# CCCC(=O)OCC(COC(=O)CCC)OC(=O)CCC                                         307.5
# COC1=C(C=CC(=C1)C=O)O                                                    285.0
#
#                                                     boiling.point.estimate.EPISuite  \
# SMILES
# CCC(C)C1CCCCC1=O                                                             218.54
# C(CCC(=O)O)CC(=O)O                                                           310.29
# CCOC(=O)C1=CC=C(C=C1)N                                                       279.90
# OC[C@H]1O[C@@H]2O[C@@H]3[C@@H](CO)O[C@@H]([C@@H...                          1607.62
# CC1=C(C(CCC1)(C)C)C=CC(=O)C                                                  262.93
# CC1(C2CCC1(C(=O)C2)C)C                                                       203.89
# CC/C=C\CCOC(=O)C                                                             176.55
# CC1=C(C(=O)CC1)O                                                             241.48
# CC(=O)OC[C@]1(O[C@H]2O[C@@H](COC(=O)C)[C@@H]([C...                           640.99
# CCCCCC1CCCC(=O)O1                                                            283.16
# CSCSC                                                                        136.67
# CCCCCCCCCCCCCCC(=O)OCC                                                       324.49
# O=C1C=C[C@]2([C@H](N1)CC[C@@H]1[C@@H]2CC[C@]2([...                           550.46
# CC(=CCC/C(=C/CCC(=O)C)/C)C                                                   260.99
# COC(C(c1ccccc1)C)OC                                                          227.23
# CCCCCCCC(=O)OCCC(C)C                                                         254.66
# CC=Cc1ccc(c(c1)OC)OC(=O)Cc1ccccc1                                            382.06
# CC(C)CC(C(=O)O)N                                                             408.10
# CC(C)C(C(=O)O)N                                                              396.49
# CC1=C(C(=O)C=CO1)O                                                           267.24
# O=C1CC(C)C2(C(=C1)CCC(C2)C(=C)C)C                                            298.76
# C1=CC=C2C(=C1)C=CC3=CC=CC=C32                                                327.31
# C1=CC=C(C=C1)CCOC(=O)C2=CC=CC=C2                                             330.98
# CCC=O                                                                         59.78
# CCOC(=O)[C@@H](N[C@H](C(=O)N1[C@H]2CCC[C@H]2C[C...                           579.38
# C/C(=C\CC/C=C(/CC/C=C(/CCC=C(C)C)\C)\C)/CC/C=C(...                           452.90
# COc1cnc(nc1)NS(=O)(=O)c1ccc(cc1)N                                            451.65
# CCCCCCC=CC=CC=O                                                              245.89
# CCCC(=O)OCC(COC(=O)CCC)OC(=O)CCC                                             330.46
# COC1=C(C=CC(=C1)C=O)O                                                        274.30
#
#                                                     boiling.point.estimate.Banks  \
# SMILES
# CCC(C)C1CCCCC1=O                                                      181.799762
# C(CCC(=O)O)CC(=O)O                                                    172.648793
# CCOC(=O)C1=CC=C(C=C1)N                                                193.292803
# OC[C@H]1O[C@@H]2O[C@@H]3[C@@H](CO)O[C@@H]([C@@H...                    453.417287
# CC1=C(C(CCC1)(C)C)C=CC(=O)C                                           218.405575
# CC1(C2CCC1(C(=O)C2)C)C                                                179.574801
# CC/C=C\CCOC(=O)C                                                      168.000914
# CC1=C(C(=O)CC1)O                                                      127.044885
# CC(=O)OC[C@]1(O[C@H]2O[C@@H](COC(=O)C)[C@@H]([C...                    397.437790
# CCCCCC1CCCC(=O)O1                                                     198.333328
# CSCSC                                                                 120.893833
# CCCCCCCCCCCCCCC(=O)OCC                                                272.353241
# O=C1C=C[C@]2([C@H](N1)CC[C@@H]1[C@@H]2CC[C@]2([...                    319.474347
# CC(=CCC/C(=C/CCC(=O)C)/C)C                                            220.109483
# COC(C(c1ccccc1)C)OC                                                   207.778992
# CCCCCCCC(=O)OCCC(C)C                                                  235.963305
# CC=Cc1ccc(c(c1)OC)OC(=O)Cc1ccccc1
CCC(=O)OCC(COC(=O)CCC)OC(=O)CCC                               1             0
# COC1=C(C=CC(=C1)C=O)O                                          0             0
#
# [30 rows x 4870 columns]

# %%
val = assigned == 'validation'
X_val = df.iloc[list(val[val].index)]
y_val = y.iloc[list(val[val].index)]
X_val
# Out:
#                                                     boiling.point.experimental  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                                 228.5
# CC(=O)OC1CC(CC=C1C)C(=C)C                                                  NaN
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                                     NaN
# C1COCCO1                                                                 101.5
# C1C(SCC(S1)O)O                                                             NaN
# CCC1=C(O)C(=O)CC1                                                          NaN
# C([C@@H](C(=O)O)N)C(=O)O                                                   NaN
# CC1(C2CCC1(C(C2)O)C)C                                                    210.0
# CC/C=C\CCOC(=O)CC1=CC=CC=C1                                                NaN
# O=CCC(CCC=C(C)C)C                                                        207.0
# CCCCCCC1CCCC(=O)O1                                                         NaN
# CCCC(=O)OC(Cc1ccccc1)(C)C                                                  NaN
# COC(=O)C1=CC=CC=C1C(=O)OC                                                283.7
# CCOC(=O)C1=CC=CO1                                                        196.8
# C(CO)O                                                                   197.3
# C=CC(OC(=O)C)(CCC=C(C)C)C                                                220.0
# CC[C@@H](C(=O)O[C@H]1C[C@@H](C)C=C2[C@H]1[C@@H]...                         NaN
# CC1CCC(C(C1)OC(=O)CC(C)C)C(C)C                                             NaN
# CCC(C)C(=O)OC                                                              NaN
# CCCCCCCCCCCC(=O)OC                                                       267.0
# COc1ccc2c(c1)[nH]c1c2CCN2[C@@H]1C[C@H]1[C@@H](C...                         NaN
# CCCCCCCCCCCCCCCCCC(=O)OCC([C@H]1OC[C@H]([C@@H]1...                         NaN
# O=CC[C@H]1C[C@@H](C)[C@H](/C=C/C=C/C[C@H](OC(=O...                         NaN
# CCCCCCCCCCCCCCCCCC(=O)O                                                  383.0
# COc1c(OC)ncnc1NS(=O)(=O)c1ccc(cc1)N                                        NaN
# C1=CC(=CC=C1N)S(=O)(=O)N                                                   NaN
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                                 NaN
# C/C(=C\C)/C(=O)O                                                         185.0
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                           NaN
# C(COCCOCCO)O                                                             285.0
#
#                                                     boiling.point.estimate.EPISuite  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                                     224.23
# CC(=O)OC1CC(CC=C1C)C(=C)C                                                    245.13
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                                       331.88
# C1COCCO1                                                                     102.77
# C1C(SCC(S1)O)O                                                               285.18
# CCC1=C(O)C(=O)CC1                                                            258.96
# C([C@@H](C(=O)O)N)C(=O)O                                                     347.74
# CC1(C2CCC1(C(C2)O)C)C                                                        209.98
# CC/C=C\CCOC(=O)CC1=CC=CC=C1                                                  304.70
# O=CCC(CCC=C(C)C)C                                                            205.07
# CCCCCCC1CCCC(=O)O1                                                           298.40
# CCCC(=O)OC(Cc1ccccc1)(C)C                                                    285.12
# COC(=O)C1=CC=CC=C1C(=O)OC                                                    248.83
# CCOC(=O)C1=CC=CO1                                                            180.88
# C(CO)O                                                                       153.53
# C=CC(OC(=O)C)(CCC=C(C)C)C                                                    228.95
# CC[C@@H](C(=O)O[C@H]1C[C@@H](C)C=C2[C@H]1[C@@H]...                           510.59
# CC1CCC(C(C1)OC(=O)CC(C)C)C(C)C                                               275.72
# CCC(C)C(=O)OC                                                                111.74
# CCCCCCCCCCCC(=O)OC                                                           264.89
# COc1ccc2c(c1)[nH]c1c2CCN2[C@@H]1C[C@H]1[C@@H](C...                           682.32
# CCCCCCCCCCCCCCCCCC(=O)OCC([C@H]1OC[C@H]([C@@H]1...                           531.23
# O=CC[C@H]1C[C@@H](C)[C@H](/C=C/C=C/C[C@H](OC(=O...                           945.78
# CCCCCCCCCCCCCCCCCC(=O)O                                                      382.05
# COc1c(OC)ncnc1NS(=O)(=O)c1ccc(cc1)N                                          475.30
# C1=CC(=CC=C1N)S(=O)(=O)N                                                     341.95
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                                   422.62
# C/C(=C\C)/C(=O)O                                                             188.47
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                             434.53
# C(COCCOCCO)O                                                                 270.06
#
#                                                     boiling.point.estimate.Banks  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                              177.316328
# CC(=O)OC1CC(CC=C1C)C(=C)C                                             220.067558
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                                265.346589
# C1COCCO1                                                               84.854923
# C1C(SCC(S1)O)O                                                        179.574801
# CCC1=C(O)C(=O)CC1                                                     147.471849
# C([C@@H](C(=O)O)N)C(=O)O                                              156.695493
# CC1(C2CCC1(C(C2)O)C)C                                                 181.799762
# CC/C=C\CCOC(=O)CC1=CC=CC=C1                                           238.867062
# O=CCC(CCC=C(C)C)C                                                     181.799762
# CCCCCCC1CCCC(=O)O1                                                    211.428545
# CCCC(=O)OC(Cc1ccccc1)(C)C                                             240.335522
# COC(=O)C1=CC=CC=C1C(=O)OC                                             219.983668
# CCOC(=O)C1=CC=CO1                                                     165.501135
# C(CO)O                                                                 23.556402
# C=CC(OC(=O)C)(CCC=C(C)C)C                                             221.751380
# CC[C@@H](C(=O)O[C@H]1C[C@@H](C)C=C2[C@H]1[C@@H]...                    330.993595
# CC1CCC(C(C1)OC(=O)CC(C)C)C(C)C                                        254.118836
# CCC(C)C(=O)OC                                                         133.197074
# CCCCCCCCCCCC(=O)OC                                                    235.963305
# COc1ccc2c(c1)[nH]c1c2CCN2[C@@H]1C[C@H]1[C@@H](C...                    384.323936
# CCCCCCCCCCCCCCCCCC(=O)OCC([C@H]1OC[C@H]([C@@H]1...                    339.566660
# O=CC[C@H]1C[C@@H](C)[C@H](/C=C/C=C/C[C@H](OC(=O...                    422.271646
# CCCCCCCCCCCCCCCCCC(=O)O                                               280.033226
# COc1c(OC)ncnc1NS(=O)(=O)c1ccc(cc1)N                                   293.025045
# C1=CC(=CC=C1N)S(=O)(=O)N                                              200.226373
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                            305.358174
# C/C(=C\C)/C(=O)O                                                      107.266851
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                      330.287078
# C(COCCOCCO)O                                                          177.271261
#
#                                                     boiling.point.estimate.Burnop  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                               211.376140
# CC(=O)OC1CC(CC=C1C)C(=C)C                                              267.379260
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                                 354.216698
# C1COCCO1                                                                79.778891
# C1C(SCC(S1)O)O                                                                NaN
# CCC1=C(O)C(=O)CC1                                                       44.898951
# C([C@@H](C(=O)O)N)C(=O)O                                               172.992208
# CC1(C2CCC1(C(C2)O)C)C                                                  103.593829
# CC/C=C\CCOC(=O)CC1=CC=CC=C1                                            304.305689
# O=CCC(CCC=C(C)C)C                                                      195.317301
# CCCCCCC1CCCC(=O)O1                                                     244.935602
# CCCC(=O)OC(Cc1ccccc1)(C)C                                              301.753599
# COC(=O)C1=CC=CC=C1C(=O)OC                                              273.191021
# CCOC(=O)C1=CC=CO1                                                      -68.150929
# C(CO)O                                                                  -4.864542
# C=CC(OC(=O)C)(CCC=C(C)C)C                                              255.476566
# CC[C@@H](C(=O)O[C@H]1C[C@@H](C)C=C2[C@H]1[C@@H]...                     465.131560
# CC1CCC(C(C1)OC(=O)CC(C)C)C(C)C                                         309.313499
# CCC(C)C(=O)OC                                                          123.402219
# CCCCCCCCCCCC(=O)OC                                                     267.811285
# COc1ccc2c(c1)[nH]c1c2CCN2[C@@H]1C[C@H]1[C@@H](C...                     503.477802
# CCCCCCCCCCCCCCCCCC(=O)OCC([C@H]1OC[C@H]([C@@H]1...                     386.482871
# O=CC[C@H]1C[C@@H](C)[C@H](/C=C/C=C/C[C@H](OC(=O...                     606.224893
# CCCCCCCCCCCCCCCCCC(=O)O                                                339.897071
# COc1c(OC)ncnc1NS(=O)(=O)c1ccc(cc1)N                                           NaN
# C1=CC(=CC=C1N)S(=O)(=O)N                                                      NaN
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                                    NaN
# C/C(=C\C)/C(=O)O                                                        98.504151
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                       431.780467
# C(COCCOCCO)O                                                           171.655200
#
#                                                     boiling.point.best.available  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                                  228.50
# CC(=O)OC1CC(CC=C1C)C(=C)C                                                 245.13
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                                    331.88
# C1COCCO1                                                                  101.50
# C1C(SCC(S1)O)O                                                            285.18
# CCC1=C(O)C(=O)CC1                                                         258.96
# C([C@@H](C(=O)O)N)C(=O)O                                                  347.74
# CC1(C2CCC1(C(C2)O)C)C                                                     210.00
# CC/C=C\CCOC(=O)CC1=CC=CC=C1                                               304.70
# O=CCC(CCC=C(C)C)C                                                         207.00
# CCCCCCC1CCCC(=O)O1                                                        298.40
# CCCC(=O)OC(Cc1ccccc1)(C)C                                                 285.12
# COC(=O)C1=CC=CC=C1C(=O)OC                                                 283.70
# CCOC(=O)C1=CC=CO1                                                         196.80
# C(CO)O                                                                    197.30
# C=CC(OC(=O)C)(CCC=C(C)C)C                                                 220.00
# CC[C@@H](C(=O)O[C@H]1C[C@@H](C)C=C2[C@H]1[C@@H]...                        510.59
# CC1CCC(C(C1)OC(=O)CC(C)C)C(C)C                                            275.72
# CCC(C)C(=O)OC                                                             111.74
# CCCCCCCCCCCC(=O)OC                                                        267.00
# COc1ccc2c(c1)[nH]c1c2CCN2[C@@H]1C[C@H]1[C@@H](C...                        682.32
# CCCCCCCCCCCCCCCCCC(=O)OCC([C@H]1OC[C@H]([C@@H]1...                        531.23
# O=CC[C@H]1C[C@@H](C)[C@H](/C=C/C=C/C[C@H](OC(=O...                        945.78
# CCCCCCCCCCCCCCCCCC(=O)O                                                   383.00
# COc1c(OC)ncnc1NS(=O)(=O)c1ccc(cc1)N                                       475.30
# C1=CC(=CC=C1N)S(=O)(=O)N                                                  341.95
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                                422.62
# C/C(=C\C)/C(=O)O                                                          185.00
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                          434.53
# C(COCCOCCO)O                                                              285.00
#
#                                                     vapor.pressure.experimental  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                           1.030000e-01
# CC(=O)OC1CC(CC=C1C)C(=C)C                                                   NaN
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                             5.120000e-04
# C1COCCO1                                                           3.810000e+01
# C1C(SCC(S1)O)O                                                              NaN
# CCC1=C(O)C(=O)CC1                                                           NaN
# C([C@@H](C(=O)O)N)C(=O)O                                                    NaN
# CC1(C2CCC1(C(C2)O)C)C                                              5.020000e-02
# CC/C=C\CCOC(=O)CC1=CC=CC=C1                                                 NaN
# O=CCC(CCC=C(C)C)C                                                           NaN
# CCCCCCC1CCCC(=O)O1                                                          NaN
# CCCC(=O)OC(Cc1ccccc1)(C)C                                                   NaN
# COC(=O)C1=CC=CC=C1C(=O)OC                                          3.080000e-03
# CCOC(=O)C1=CC=CO1                                                  4.050000e-01
# C(CO)O                                                             9.200000e-02
# C=CC(OC(=O)C)(CCC=C(C)C)C                                          1.110000e-01
# CC[C@@H](C(=O)O[C@H]1C[C@@H](C)C=C2[C@H]1[C@@H]...                          NaN
# CC1CCC(C(C1)OC(=O)CC(C)C)C(C)C                                              NaN
# CCC(C)C(=O)OC                                                               NaN
# CCCCCCCCCCCC(=O)OC                                                 4.110000e-03
# COc1ccc2c(c1)[nH]c1c2CCN2[C@@H]1C[C@H]1[C@@H](C...                          NaN
# CCCCCCCCCCCCCCCCCC(=O)OCC([C@H]1OC[C@H]([C@@H]1...                          NaN
# O=CC[C@H]1C[C@@H](C)[C@H](/C=C/C=C/C[C@H](OC(=O...                          NaN
# CCCCCCCCCCCCCCCCCC(=O)O                                            2.120000e-08
# COc1c(OC)ncnc1NS(=O)(=O)c1ccc(cc1)N                                         NaN
# C1=CC(=CC=C1N)S(=O)(=O)N                                                    NaN
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                                  NaN
# C/C(=C\C)/C(=O)O                                                   1.330000e-01
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                            NaN
# C(COCCOCCO)O                                                       1.320000e-03
#
#                                                     vapor.pressure.best.available  \
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                             1.030000e-01
# CC(=O)OC1CC(CC=C1C)C(=C)C                                            3.530000e-02
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                               5.120000e-04
# C1COCCO1                                                             3.810000e+01
# C1C(SCC(S1)O)O                                                       6.600000e-05
# CCC1=C(O)C(=O)CC1                                                    1.030000e-03
# C([C@@H](C(=O)O)N)C(=O)O                                             2.620000e-07
# CC1(C2CCC1(C(C2)O)C)C                                                5.020000e-02
# CC/C=C\CCOC(=O)CC1=CC=CC=C1                                          8.740000e-04
# O=CCC(CCC=C(C)C)C                                                    2.540000e-01
# CCCCCCC1CCCC(=O)O1                                                   1.960000e-03
# CCCC(=O)OC(Cc1ccccc1)(C)C                                            2.570000e-03
# COC(=O)C1=CC=CC=C1C(=O)OC                                            3.080000e-03
# CCOC(=O)C1=CC=CO1                                                    4.050000e-01
# C(CO)O                                                               9.200000e-02
# C=CC(OC(=O)C)(CCC=C(C)C)C                                            1.110000e-01
# CC[C@@H](C(=O)O[C@H]1C[C@@H](C)C=C2[C@H]1[C@@H]...                   1.340000e-12
# CC1CCC(C(C1)OC(=O)CC(C)C)C(C)C                                       6.740000e-03
# CCC(C)C(=O)OC                                                        2.250000e+01
# CCCCCCCCCCCC(=O)OC                                                   4.110000e-03
# COc1ccc2c(c1)[nH]c1c2CCN2[C@@H]1C[C@H]1[C@@H](C...                   1.180000e-15
# CCCCCCCCCCCCCCCCCC(=O)OCC([C@H]1OC[C@H]([C@@H]1...                   9.240000e-13
# O=CC[C@H]1C[C@@H](C)[C@H](/C=C/C=C/C[C@H](OC(=O...                   9.870000e-31
# CCCCCCCCCCCCCCCCCC(=O)O                                              2.120000e-08
# COc1c(OC)ncnc1NS(=O)(=O)c1ccc(cc1)N                                  2.150000e-09
# C1=CC(=CC=C1N)S(=O)(=O)N                                             7.320000e-06
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C
# COc1ccc2c(c1)[nH]c1c2CCN2[C@@H]1C[C@H]1[C@@H](C...              0
# CCCCCCCCCCCCCCCCCC(=O)OCC([C@H]1OC[C@H]([C@@H]1...              0
# O=CC[C@H]1C[C@@H](C)[C@H](/C=C/C=C/C[C@H](OC(=O...              0
# CCCCCCCCCCCCCCCCCC(=O)O                                         0
# COc1c(OC)ncnc1NS(=O)(=O)c1ccc(cc1)N                             1
# C1=CC(=CC=C1N)S(=O)(=O)N                                        0
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                      0
# C/C(=C\C)/C(=O)O                                                0
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                0
# C(COCCOCCO)O                                                    0
#
#                                                     Infective.80  Infective.50
# SMILES
# CC1=CC[C@H](CC1=O)C(=C)C                                       1             0
# CC(=O)OC1CC(CC=C1C)C(=C)C                                      1             0
# CC1CC(C)(C)c2c(C1(C)C)cc(c(c2)C(=O)C)C                         1             0
# C1COCCO1                                                       0             0
# C1C(SCC(S1)O)O                                                 0             0
# CCC1=C(O)C(=O)CC1                                              0             0
# C([C@@H](C(=O)O)N)C(=O)O                                       0             0
# CC1(C2CCC1(C(C2)O)C)C                                          1             0
# CC/C=C\CCOC(=O)CC1=CC=CC=C1                                    1             0
# O=CCC(CCC=C(C)C)C                                              0             0
# CCCCCCC1CCCC(=O)O1                                             1             0
# CCCC(=O)OC(Cc1ccccc1)(C)C                                      1             0
# COC(=O)C1=CC=CC=C1C(=O)OC                                      1             0
# CCOC(=O)C1=CC=CO1                                              0             0
# C(CO)O                                                         0             0
# C=CC(OC(=O)C)(CCC=C(C)C)C                                      1             0
# CC[C@@H](C(=O)O[C@H]1C[C@@H](C)C=C2[C@H]1[C@@H]...             0             0
# CC1CCC(C(C1)OC(=O)CC(C)C)C(C)C                                 1             0
# CCC(C)C(=O)OC                                                  0             0
# CCCCCCCCCCCC(=O)OC                                             1             0
# COc1ccc2c(c1)[nH]c1c2CCN2[C@@H]1C[C@H]1[C@@H](C...             0             0
# CCCCCCCCCCCCCCCCCC(=O)OCC([C@H]1OC[C@H]([C@@H]1...             0             0
# O=CC[C@H]1C[C@@H](C)[C@H](/C=C/C=C/C[C@H](OC(=O...             0             0
# CCCCCCCCCCCCCCCCCC(=O)O                                        0             0
# COc1c(OC)ncnc1NS(=O)(=O)c1ccc(cc1)N                            1             1
# C1=CC(=CC=C1N)S(=O)(=O)N                                       1             0
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                     0             0
# C/C(=C\C)/C(=O)O                                               0             0
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O               1             0
# C(COCCOCCO)O                                                   0             0
#
# [30 rows x 4870 columns]

# %%
X_train = X_train_t.append(X_val)
y_train = y_train_t.append(y_val)
X_train
# Out:
#                                                   boiling.point.experimental  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                               NaN
# CC1=CCC(CC1)(O)C(C)C                                                   209.0
# CC1=CC[C@](CC1)(O)C(C)C                                                209.0
# O=C1C2(C)CCC(C1(C)C)C2                                                 193.0
# OCC1=CC[C@H](CC1)C(=C)C                                                244.0
# ...                                                                      ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                                 NaN
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                               NaN
# C/C(=C\C)/C(=O)O                                                       185.0
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                         NaN
# C(COCCOCCO)O                                                           285.0
#
#                                                   boiling.point.estimate.EPISuite  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                                 262.43
# CC1=CCC(CC1)(O)C(C)C                                                       211.85
# CC1=CC[C@](CC1)(O)C(C)C                                                    211.85
# O=C1C2(C)CCC(C1(C)C)C2                                                     203.89
# OCC1=CC[C@H](CC1)C(=C)C                                                    241.19
# ...                                                                           ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                                   341.95
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                                 422.62
# C/C(=C\C)/C(=O)O                                                           188.47
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                           434.53
# C(COCCOCCO)O                                                               270.06
#
#                                                   boiling.point.estimate.Banks  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                          231.359855
# CC1=CCC(CC1)(O)C(C)C                                                181.799762
# CC1=CC[C@](CC1)(O)C(C)C                                             181.799762
# O=C1C2(C)CCC(C1(C)C)C2                                              179.574801
# OCC1=CC[C@H](CC1)C(=C)C                                             179.574801
# ...                                                                        ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                            200.226373
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                          305.358174
# C/C(=C\C)/C(=O)O                                                    107.266851
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                    330.287078
# C(COCCOCCO)O                                                        177.271261
#
#                                                   boiling.point.estimate.Burnop  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                           283.769094
# CC1=CCC(CC1)(O)C(C)C                                                 205.923187
# CC1=CC[C@](CC1)(O)C(C)C                                              205.923187
# O=C1C2(C)CCC(C1(C)C)C2                                               104.485216
# OCC1=CC[C@H](CC1)C(=C)C                                              208.589955
# ...                                                                         ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                                    NaN
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                                  NaN
# C/C(=C\C)/C(=O)O                                                      98.504151
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                     431.780467
# C(COCCOCCO)O                                                         171.655200
#
#                                                   boiling.point.best.available  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                              262.43
# CC1=CCC(CC1)(O)C(C)C                                                    209.00
# CC1=CC[C@](CC1)(O)C(C)C                                                 209.00
# O=C1C2(C)CCC(C1(C)C)C2                                                  193.00
# OCC1=CC[C@H](CC1)C(=C)C                                                 244.00
# ...                                                                        ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                                341.95
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                              422.62
# C/C(=C\C)/C(=O)O                                                        185.00
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                        434.53
# C(COCCOCCO)O                                                            285.00
#
#                                                   vapor.pressure.experimental  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                                NaN
# CC1=CCC(CC1)(O)C(C)C                                                      NaN
# CC1=CC[C@](CC1)(O)C(C)C                                                   NaN
# O=C1C2(C)CCC(C1(C)C)C2                                                0.81700
# OCC1=CC[C@H](CC1)C(=C)C                                                   NaN
# ...                                                                       ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                                  NaN
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                                NaN
# C/C(=C\C)/C(=O)O                                                      0.13300
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                          NaN
# C(COCCOCCO)O                                                          0.00132
#
#                                                   vapor.pressure.best.available  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                         1.390000e-02
# CC1=CCC(CC1)(O)C(C)C                                               4.270000e-02
# CC1=CC[C@](CC1)(O)C(C)C                                            4.270000e-02
# O=C1C2(C)CCC(C1(C)C)C2                                             8.170000e-01
# OCC1=CC[C@H](CC1)C(=C)C                                            4.780000e-03
# ...                                                                         ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                           7.320000e-06
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                         1.780000e-08
# C/C(=C\C)/C(=O)O                                                   1.330000e-01
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                   1.260000e-09
# C(COCCOCCO)O                                                       1.320000e-03
#
#                                                       MW    AMW      Sv  ...  \
# SMILES                                                                   ...
# CCC(=O)OC1CC(CC=C1C)C(=C)C                        208.33  5.952  19.698  ...
# CC1=CCC(CC1)(O)C(C)C                              154.28  5.320  15.456  ...
# CC1=CC[C@](CC1)(O)C(C)C                           154.28  5.320  15.456  ...
# O=C1C2(C)CCC(C1(C)C)C2                            152.26  5.639  14.929  ...
# OCC1=CC[C@H](CC1)C(=C)C                           152.26  5.639  14.929  ...
# ...                                                  ...    ...     ...  ...
# C1=CC(=CC=C1N)S(=O)(=O)N                          172.23  9.065  12.240  ...
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C        337.63  5.821  31.879  ...
# C/C(=C\C)/C(=O)O                                  100.13  6.675   8.537  ...
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O  402.54  6.493  34.674  ...
# C(COCCOCCO)O                                      150.20  6.258  12.547  ...
#
#                                                   Psychotic.80  Psychotic.50  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                   0             0
# CC1=CCC(CC1)(O)C(C)C                                         0             0
# CC1=CC[C@](CC1)(O)C(C)C                                      0             0
# O=C1C2(C)CCC(C1(C)C)C2                                       0             0
# OCC1=CC[C@H](CC1)C(=C)C                                      0             0
# ...                                                        ...           ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                     0             0
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                   0             0
# C/C(=C\C)/C(=O)O                                             0             0
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O             1             0
# C(COCCOCCO)O                                                 0             0
#
#                                                   Hypertens.80  Hypertens.50  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                   1             0
# CC1=CCC(CC1)(O)C(C)C                                         0             0
# CC1=CC[C@](CC1)(O)C(C)C                                      0             0
# O=C1C2(C)CCC(C1(C)C)C2                                       0             0
# OCC1=CC[C@H](CC1)C(=C)C                                      0             0
# ...                                                        ...           ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                     0             0
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                   0             0
# C/C(=C\C)/C(=O)O                                             0             0
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O             1             0
# C(COCCOCCO)O                                                 0             0
#
#                                                   Hypnotic.80  Hypnotic.50  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                  1            0
# CC1=CCC(CC1)(O)C(C)C                                        0            0
# CC1=CC[C@](CC1)(O)C(C)C                                     0            0
# O=C1C2(C)CCC(C1(C)C)C2                                      0            0
# OCC1=CC[C@H](CC1)C(=C)C                                     0            0
# ...                                                       ...          ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                    0            0
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                  0            0
# C/C(=C\C)/C(=O)O                                            0            0
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O            0            0
# C(COCCOCCO)O                                                0            0
#
#                                                   Neoplastic.80  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                    1
# CC1=CCC(CC1)(O)C(C)C                                          0
# CC1=CC[C@](CC1)(O)C(C)C                                       0
# O=C1C2(C)CCC(C1(C)C)C2                                        0
# OCC1=CC[C@H](CC1)C(=C)C                                       0
# ...                                                         ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                      0
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                    0
# C/C(=C\C)/C(=O)O                                              0
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O              1
# C(COCCOCCO)O                                                  0
#
#                                                   Neoplastic.50  Infective.80  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                    0             1
# CC1=CCC(CC1)(O)C(C)C                                          0             1
# CC1=CC[C@](CC1)(O)C(C)C                                       0             1
# O=C1C2(C)CCC(C1(C)C)C2                                        0             1
# OCC1=CC[C@H](CC1)C(=C)C                                       0             1
# ...                                                         ...           ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                      0             1
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                    0             0
# C/C(=C\C)/C(=O)O                                              0             0
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O              0             1
# C(COCCOCCO)O                                                  0             0
#
#                                                   Infective.50
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                   0
# CC1=CCC(CC1)(O)C(C)C                                         0
# CC1=CC[C@](CC1)(O)C(C)C                                      0
# O=C1C2(C)CCC(C1(C)C)C2                                       0
# OCC1=CC[C@H](CC1)C(=C)C                                      0
# ...                                                        ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                     0
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                   0
# C/C(=C\C)/C(=O)O                                             0
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O             0
# C(COCCOCCO)O                                                 0
#
# [1894 rows x 4870 columns]

# %%
y_train
# Out:
# 2       True
# 4       True
# 5       True
# 6       True
# 7       True
#        ...
# 113    False
# 114    False
# 118     True
# 122    False
# 124     True
# Name: odor.class, Length: 1894, dtype: bool

# %%
percentage_odorless = y_train.value_counts()[False]/y_train.shape[0]
percentage_odor = 1 - percentage_odorless
print(f"Total number molecules in training set: {y_train.shape[0]}")
print(f"Odor: {y_train.value_counts()[True]}")
print(f"Odorless: {y_train.value_counts()[False]}")

print(f"\nTotal number molecules in test set: {y_test.shape[0]}")
print(f"Odor: {y_test.value_counts()[True]}")
print(f"Odorless: {y_test.value_counts()[False]}")

print(f"\nPercentage odorless {y_test.value_counts()[False]/y_test.shape[0]}")
# Out:
# Total number molecules in training set: 1894
# Odor: 1595
# Odorless: 299
#
# Total number molecules in test set: 30
# Odor: 20
# Odorless: 10
#
# Percentage odorless 0.3333333333333333

# %% [markdown]
# ### Validation set

# %%
print("Number of training samples:", len(X_train_t))
print("Number of validation samples:", len(X_val))
# Out:
# Number of training samples: 1864
# Number of validation samples: 30

# %% [markdown]
# # Test Model

# %%
def test_model(model, y_test, X_test, verbose=True):
    y_pred=model.predict(X_test)
    y_pred_probs=model.predict_proba(X_test)[:,1]
    
    if verbose:
        print("ROC_AUC (TEST):",metrics.roc_auc_score(y_test, y_pred_probs))
        print("\n\nCLASSIFICATION REPORT:\n",metrics.classification_report(y_test, y_pred))
        
        if hasattr(model, 'feature_importances_') and hasattr(X_test, 'columns'):
            feature_imp = pd.Series(model.feature_importances_,index=X_test.columns.values).sort_values(ascending=False)
            top_20 = feature_imp.nlargest(20)
            sns.barplot(x=top_20, y=top_20.index)
            plt.xlabel('Descriptor Importance Score')
            plt.ylabel('Descriptor')
            plt.title("Top descriptors")
            plt.show()
        
        fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_probs)  
        
        #create ROC curve
        plt.plot(fpr,tpr)
        plt.ylabel('True Positive Rate')
        plt.xlabel('False Positive Rate')
        plt.show()
        
    return metrics.roc_auc_score(y_test, y_pred_probs) 

def test_model_cross_val(model, y_test, X_test, k=5, verbose=True):
    roc_auc_nans = cross_val_score(model, X_test, y_test, cv=k, scoring='roc_auc')
    print(f"AVERAGE CV={k} ROC_AUC (TEST): {np.mean(roc_auc_nans)}")
    print(f"AVERAGE CV={k} STD (TEST): {np.std(roc_auc_nans)}")

# %% [markdown]
# # Handle Non Important Descriptors

# %% [markdown]
# 1. Remove values below threshold e.g. 0, any descriptors with 0 importance
# 2. Get the top N descriptors

# %%
def handle_importance(model, X_train, X_test=pd.DataFrame(), threshold=-1, n=-1, verbose=None):
    feature_imp = pd.Series(model.feature_importances_,index=X_train.columns.values).sort_values(ascending=False)
    if threshold >= 0:
        feature_imp = feature_imp[feature_imp > threshold]
    
    if n >= 0: 
        feature_imp = feature_imp.nlargest(n)
        
    if verbose: 
        print(feature_imp)
        
    X_train = X_train.loc[:, feature_imp.axes[0].tolist()]
    
    if not X_test.empty:
        X_test = X_test.loc[:, feature_imp.axes[0].tolist()]

    return X_train, X_test, model

# %%
def optimiseImportance(model, X_tr, y_tr, k=5, verbose=True):
    
    imp_params = [
              {"threshold":-1, 'n':5}, 
              {"threshold":-1, 'n':10}, 
              {"threshold":-1, 'n':25}, 
              {"threshold":-1, 'n':50},
              {"threshold":-1, 'n':100}, 
              {"threshold":-1, 'n':200}, 
              {"threshold":-1, 'n':400}, 
              {"threshold":-1, 'n':800},
              {"threshold":-1, 'n':X_tr.shape[1]}]

    print(f"Cross validated importance experiment with k={k}")
    
    imp_df = pd.DataFrame(columns=['Most important N descriptors', 'Average ROC_AUC', 'Standard Deviation'])

    for imp_param in imp_params: 
        name = (f"Threshold:{imp_param['threshold']}N:{imp_param['n']}".replace("N:-1", '')).replace("Threshold:-1", '')
        
        if verbose:
            print(name)
        
        X_tr_temp , _, _ = handle_importance(model, 
                                            X_tr.copy(), 
                                            threshold=imp_param['threshold'], 
                                            n=imp_param['n'])
                
        roc_auc_nans = cross_val_score(model, X_tr_temp, y_tr, cv=k, scoring='roc_auc')
        
        imp_df = imp_df.append({'Most important N descriptors': imp_param['n'], 
                               'Average ROC_AUC':np.mean(roc_auc_nans), 
                               'Standard Deviation':np.std(roc_auc_nans)}, 
                                ignore_index = True)

    if verbose:
        fig = imp_df.plot(kind="bar", x="Most important N descriptors", y="Average ROC_AUC", yerr="Standard Deviation", title=f"ROC_AUC after filtering descriptors by importance CV={k}", legend=False)
        
        plt.ylim(0.85,1)
        
    return imp_df

# %% [markdown]
# # Handle NaNs

# %% [markdown]
# - You cannot have any missing values in the random forest model, you can in XGB
# - You cannot have mismatched features between columns in the random forest model
# - 3 options
#     1. Remove any columns with missing values
#     2. Remove columns above threshold percentange NaNs e.g. 60% NaNs.
#     3. Remove columns above threshold percentange NaNs e.g. 60% NaNs. Replace columns below threshold with missing values with the mean value.

# %%
def handleNaNs(X_tr, X_te, option=1, thresh=0.6): 
    if option == 1:
        nans =  X.columns[X.isna().any()].tolist()
        X_tr.drop(nans, inplace = True, axis=1)
        X_te.drop(nans, inplace = True, axis=1)
    else: 
        nans = X.isna().mean(axis=0)
        # set threshold for percentage nans before we drop 
        X_thresh = nans[nans >= thresh]
        X_tr.drop(X_thresh.index, 
          axis=1, 
          inplace=True)
        X_te.drop(X_thresh.index, 
          axis=1, 
          inplace=True)
        
        if option == 3: 
            X_tr.fillna(X_train.mean(), inplace=True) 
            X_te.fillna(X_test.mean(), inplace=True)
    
    return X_tr, X_te

# %%
def optimiseNaNs(model, X_train, X_test, y_train, y_test, option=2, k=5, verbose=True): 
    print(f"Cross validated missing values experiment with k={k}")
    
    percentages = [x/100 for x in range(0, 100, 10)] 
    nans_df = pd.DataFrame(columns=['Name', 'Average ROC_AUC', 'Standard Deviation'])

    for perc in percentages: 
        name = str(perc)
        if perc == 0:
            X_train_cv, _  = handleNaNs(X_train.copy(), X_test.copy(), option=1)
        else:
            X_train_cv, _  = handleNaNs(X_train.copy(), X_test.copy(), option=option, thresh=perc)

        roc_auc_nans = cross_val_score(model, X_train_cv, y_train, cv=k, scoring='roc_auc')
        
        nans_df = nans_df.append({'Name': name, 
                                   'Average ROC_AUC':np.mean(roc_auc_nans), 
                                   'Standard Deviation':np.std(roc_auc_nans)}, 
                                    ignore_index = True)

    if verbose:
        fig = nans_df.plot(kind="bar", x="Name", y="Average ROC_AUC", yerr="Standard Deviation", title=f"ROC_AUC after thresholding descriptors by % NaNs CV={k}", legend=False)
        plt.ylim(0.85,0.98)
        
    return nans_df

# %% [markdown]
# # Random Forest Model

# %% [markdown]
# https://www.datacamp.com/tutorial/random-forests-classifier-python

# %%
# set random state to 0 to allow reproducible results
clf=RandomForestClassifier(random_state=SEED) 

# For readability
y_train_rf = y_train
y_test_rf = y_test
X_train_rf = X_train
X_test_rf = X_test

# %% [markdown]
# ## Handle NaNs RF

# %%
# choose optimal threshold for removing columns with NaNs
optimiseNaNs(clf, X_train_rf, X_test_rf, y_train_rf, y_test_rf, option=3)
# Out:
# Cross validated missing values experiment with k=5
#   Name  Average ROC_AUC  Standard Deviation
# 0  0.0         0.923656            0.044043
# 1  0.1         0.919254            0.046958
# 2  0.2         0.921490            0.045213
# 3  0.3         0.921490            0.045213
# 4  0.4         0.917761            0.050319
# 5  0.5         0.921226            0.047298
# 6  0.6         0.921226            0.047298
# 7  0.7         0.921226            0.047298
# 8  0.8         0.921226            0.047298
# 9  0.9         0.921226            0.047298

# %% [markdown]
# let's just go with removing all the columns with missing values

# %%
X_train_rf, X_test_rf = handleNaNs(X_train.copy(), X_test.copy(), option=1)

# %%
clf.fit(X_train_rf, y_train_rf)
print("Validation performance of Random Forest after removing all columns with NaNs")
test_model_cross_val(clf, y_train_rf, X_train_rf, k=5, verbose=True)
# Out:
# Validation performance of Random Forest after removing all columns with NaNs
# AVERAGE CV=5 ROC_AUC (TEST): 0.923655579760197
# AVERAGE CV=5 STD (TEST): 0.044042671974349724

# %% [markdown]
# ## Using Importance to reduce dimensionality

# %%
clf.fit(X_train_rf, y_train_rf)
optimiseImportance(clf, X_train_rf, y_train_rf)
# Out:
# Cross validated importance experiment with k=5
# N:5
# N:10
# N:25
# N:50
# N:100
# N:200
# N:400
# N:800
# N:4866
#    Most important N descriptors  Average ROC_AUC  Standard Deviation
# 0                           5.0         0.914705            0.059106
# 1                          10.0         0.921881            0.055872
# 2                          25.0         0.927357            0.051099
# 3                          50.0         0.929760            0.048681
# 4                         100.0         0.934561            0.043885
# 5                         200.0         0.930842            0.046174
# 6                         400.0         0.930431            0.044574
# 7                         800.0         0.928820            0.044700
# 8                        4866.0         0.920574            0.045329

# %% [markdown]
# ### Remove labels

# %%
clf.fit(X_train_rf, y_train_rf)
X_train_rf, X_test_rf, clf = handle_importance(clf, 
                                               X_train_rf, 
                                               X_test_rf, 
                                               threshold=-1, 
                                               n=400)

# %%
clf.fit(X_train_rf, y_train_rf)
print("Validation set performance of Random Forest after removing labels")
test_model_cross_val(clf, y_train_rf, X_train_rf, k=5, verbose=True)
# Out:
# Validation set performance of Random Forest after removing labels
# AVERAGE CV=5 ROC_AUC (TEST): 0.9304314329738059
# AVERAGE CV=5 STD (TEST): 0.044573573571218245

# %%
X_train_rf
# Out:
#                                                   boiling.point.best.available  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                              262.43
# CC1=CCC(CC1)(O)C(C)C                                                    209.00
# CC1=CC[C@](CC1)(O)C(C)C                                                 209.00
# O=C1C2(C)CCC(C1(C)C)C2                                                  193.00
# OCC1=CC[C@H](CC1)C(=C)C                                                 244.00
# ...                                                                        ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                                341.95
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                              422.62
# C/C(=C\C)/C(=O)O                                                        185.00
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                        434.53
# C(COCCOCCO)O                                                            285.00
#
#                                                   SM2_B.s.  TPSA.NO.  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                           4.972     26.30
# CC1=CCC(CC1)(O)C(C)C                                 4.517     20.23
# CC1=CC[C@](CC1)(O)C(C)C                              4.517     20.23
# O=C1C2(C)CCC(C1(C)C)C2                               4.647     17.07
# OCC1=CC[C@H](CC1)C(=C)C                              4.583     20.23
# ...                                                    ...       ...
# C1=CC(=CC=C1N)S(=O)(=O)N                             5.233     86.18
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C           5.071     32.26
# C/C(=C\C)/C(=O)O                                     4.799     37.30
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O     5.964    116.20
# C(COCCOCCO)O                                         4.866     58.92
#
#                                                   vapor.pressure.best.available  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                         1.390000e-02
# CC1=CCC(CC1)(O)C(C)C                                               4.270000e-02
# CC1=CC[C@](CC1)(O)C(C)C                                            4.270000e-02
# O=C1C2(C)CCC(C1(C)C)C2                                             8.170000e-01
# OCC1=CC[C@H](CC1)C(=C)C                                            4.780000e-03
# ...                                                                         ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                           7.320000e-06
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                         1.780000e-08
# C/C(=C\C)/C(=O)O                                                   1.330000e-01
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                   1.260000e-09
# C(COCCOCCO)O                                                       1.320000e-03
#
#                                                   SpMax3_Bh.s.  P_VSA_p_2  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                               4.529     36.145
# CC1=CCC(CC1)(O)C(C)C                                     4.130     42.683
# CC1=CC[C@](CC1)(O)C(C)C                                  4.130     42.683
# O=C1C2(C)CCC(C1(C)C)C2                                   3.975     25.145
# OCC1=CC[C@H](CC1)C(=C)C                                  4.320     42.683
# ...                                                        ...        ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                 5.108    108.502
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C               4.323     60.694
# C/C(=C\C)/C(=O)O                                         4.359     67.828
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O         7.428    176.263
# C(COCCOCCO)O                                             4.648    107.366
#
#                                                   SpAbs_B.s.    SAacc  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                            36.049   36.145
# CC1=CCC(CC1)(O)C(C)C                                  25.181   42.683
# CC1=CC[C@](CC1)(O)C(C)C                               25.181   42.683
# O=C1C2(C)CCC(C1(C)C)C2                                26.169   25.145
# OCC1=CC[C@H](CC1)C(=C)C                               25.847   42.683
# ...                                                      ...      ...
# C1=CC(=CC=C1N)S(=O)(=O)N                              36.527  108.502
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C            48.018   60.694
# C/C(=C\C)/C(=O)O                                      23.246   67.828
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O      79.537  176.263
# C(COCCOCCO)O                                          28.000  107.366
#
#                                                   Psi_i_s     RTs  ...  \
# SMILES                                                             ...
# CCC(=O)OC1CC(CC=C1C)C(=C)C                         33.667  51.476  ...
# CC1=CCC(CC1)(O)C(C)C                               22.750  46.460  ...
# CC1=CC[C@](CC1)(O)C(C)C                            22.750  46.452  ...
# O=C1C2(C)CCC(C1(C)C)C2                             23.000  48.600  ...
# OCC1=CC[C@H](CC1)C(=C)C                            23.667  45.413  ...
# ...                                                   ...     ...  ...
# C1=CC(=CC=C1N)S(=O)(=O)N                           34.250  83.852  ...
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C         44.167  58.565  ...
# C/C(=C\C)/C(=O)O                                   22.333  56.390  ...
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O   76.750  88.844  ...
# C(COCCOCCO)O                                       28.000  50.409  ...
#
#                                                   Mor14p  SpMin2_Bh.e.  MPC02  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                         1.098         1.592  3.045
# CC1=CCC(CC1)(O)C(C)C                               1.294         1.587  2.833
# CC1=CC[C@](CC1)(O)C(C)C                            1.293         1.587  2.833
# O=C1C2(C)CCC(C1(C)C)C2                             0.949         1.636  3.091
# OCC1=CC[C@H](CC1)C(=C)C                            1.117         1.561  2.708
# ...                                                  ...           ...    ...
# C1=CC(=CC=C1N)S(=O)(=O)N                          -0.110         1.461  2.833
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C         1.239         1.798  3.367
# C/C(=C\C)/C(=O)O                                   0.249         1.133  2.079
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O   1.776         1.683  3.555
# C(COCCOCCO)O                                       0.490         1.445  2.197
#
#                                                     E2m    O.  SpMAD_Dz.p.  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                        0.178   5.7        8.745
# CC1=CCC(CC1)(O)C(C)C                              0.177   3.4        5.209
# CC1=CC[C@](CC1)(O)C(C)C                           0.177   3.4        5.209
# O=C1C2(C)CCC(C1(C)C)C2                            0.326   3.7        4.291
# OCC1=CC[C@H](CC1)C(=C)C                           0.125   3.7        5.544
# ...                                                 ...   ...          ...
# C1=CC(=CC=C1N)S(=O)(=O)N                          0.128  10.5        4.043
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C        0.234   1.7       12.500
# C/C(=C\C)/C(=O)O                                  0.177  13.3        4.187
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O  0.175  12.9       15.822
# C(COCCOCCO)O                                      0.221  16.7       12.243
#
#                                                      RTe  RDF020i  SdsN  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                        23.454    5.354   0.0
# CC1=CCC(CC1)(O)C(C)C                              22.698    4.535   0.0
# CC1=CC[C@](CC1)(O)C(C)C                           22.697    4.519   0.0
# O=C1C2(C)CCC(C1(C)C)C2                            22.825    1.086   0.0
# OCC1=CC[C@H](CC1)C(=C)C                           21.790    7.405   0.0
# ...                                                  ...      ...   ...
# C1=CC(=CC=C1N)S(=O)(=O)N                          16.669    3.012   0.0
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C        29.067   10.317   0.0
# C/C(=C\C)/C(=O)O                                  14.251    2.718   0.0
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O  31.903   13.942   0.0
# C(COCCOCCO)O                                      19.247   14.063   0.0
#
#                                                   Mor27u
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                        -0.098
# CC1=CCC(CC1)(O)C(C)C                               0.151
# CC1=CC[C@](CC1)(O)C(C)C                            0.146
# O=C1C2(C)CCC(C1(C)C)C2                             0.269
# OCC1=CC[C@H](CC1)C(=C)C                            0.024
# ...                                                  ...
# C1=CC(=CC=C1N)S(=O)(=O)N                           0.027
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C         0.504
# C/C(=C\C)/C(=O)O                                   0.057
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O   0.266
# C(COCCOCCO)O                                      -0.330
#
# [1894 rows x 400 columns]

# %% [markdown]
# ## Tuning the hyperparamaters

# %%
# Look at parameters used by our current forest
print('Parameters currently in use:\n')
print(clf.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': 0, 'verbose': 0, 'warm_start': False}

# %%
# Use the grid to search for best hyperparameters
# Takes ~ 10 minutes to run 

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 2000, num = 50)]
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 20, num = 50)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 20, 40, 60, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 3, 4, 5, 10]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Criterion 
criterion = ['gini', 'entropy']

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap, 
               'criterion': criterion}

# Random search of parameters, using 5 fold cross validation, 
# search across 500 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator=clf, param_distributions = random_grid, n_iter = 500, cv = 5, verbose=1, random_state=SEED, n_jobs = -1)
# Fit the random search model
rf_random.fit(X_train_rf, y_train_rf)

# Print best paramaters 
print(rf_random.best_params_)
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# {'n_estimators': 659, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 10, 'criterion': 'entropy', 'bootstrap': False}

# %%
rf_random.best_estimator_.get_params()
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': 10,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 659,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %%
tuned_rf= RandomForestClassifier(n_estimators=50,
                                 min_samples_split=20,
                                 min_samples_leaf=1,
                                 max_features='sqrt',
                                 max_depth=10,
                                 criterion='gini',
                                 bootstrap=False,
                                 random_state=SEED)
tuned_rf=RandomForestClassifier(**rf_random.best_params_,
                                 random_state=SEED)
tuned_rf.fit(X_train_rf, y_train_rf)
# Out:
# RandomForestClassifier(bootstrap=False, criterion='entropy', max_depth=10,
#                        min_samples_leaf=4, n_estimators=659, random_state=0)

# %%
tuned_rf.fit(X_train_rf, y_train_rf)
print("Final tuned validation set performance of Random Forest")
test_model_cross_val(tuned_rf, y_train_rf, X_train_rf, k=5, verbose=True)
# Out:
# Final tuned validation set performance of Random Forest
# AVERAGE CV=5 ROC_AUC (TEST): 0.9346608398420205
# AVERAGE CV=5 STD (TEST): 0.04080690965301417

# %%
tuned_rf.fit(X_train_rf, y_train_rf)
test_model(tuned_rf, y_test_rf, X_test_rf)
# Out:
# ROC_AUC (TEST): 0.9750000000000001
#
#
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#        False       1.00      0.80      0.89        10
#         True       0.91      1.00      0.95        20
#
#     accuracy                           0.93        30
#    macro avg       0.95      0.90      0.92        30
# weighted avg       0.94      0.93      0.93        30
# 0.9750000000000001

# %% [markdown]
# # XgBoost
#
# https://practicaldatascience.co.uk/machine-learning/how-to-create-a-classification-model-using-xgboost

# %%
# for readibility 
y_train_xgb = y_train
y_test_xgb = y_test
X_train_xgb = X_train
X_test_xgb = X_test

# %% [markdown]
# ## Create model

# %%
X_train_xgb.columns = X_train_xgb.columns.str.translate("".maketrans({"[":"{", "]":"}","<":"^"}))
X_test_xgb.columns = X_test_xgb.columns.str.translate("".maketrans({"[":"{", "]":"}","<":"^"}))

xgb = XGBClassifier(random_state=SEED)
xgb.fit(X_train_xgb, y_train_xgb)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=0, ...)

# %%
# Baseline results
print("Baseline performance of XGBoost")
test_model_cross_val(xgb, y_train_xgb, X_train_xgb, k=5, verbose=True)
# Out:
# Baseline performance of XGBoost
# AVERAGE CV=5 ROC_AUC (TEST): 0.9303962772080832
# AVERAGE CV=5 STD (TEST): 0.04436666576440176

# %% [markdown]
# ## Handle NaNs

# %%
# choose optimal threshold for removing columns with NaNs
optimiseNaNs(xgb, X_train_xgb, X_test_xgb, y_train_xgb, y_test_xgb, option=2)
# Out:
# Cross validated missing values experiment with k=5
#   Name  Average ROC_AUC  Standard Deviation
# 0  0.0         0.930488            0.043904
# 1  0.1         0.933163            0.040375
# 2  0.2         0.931055            0.042958
# 3  0.3         0.931055            0.042958
# 4  0.4         0.929492            0.045152
# 5  0.5         0.930396            0.044367
# 6  0.6         0.930396            0.044367
# 7  0.7         0.930396            0.044367
# 8  0.8         0.930396            0.044367
# 9  0.9         0.930396            0.044367

# %% [markdown]
# Choose to remove columns with NaNs > 0.7

# %%
X_train_xgb, X_test_xgb = handleNaNs(X_train_xgb.copy(), X_test_xgb.copy(), option=2, thresh=0.7)
X_train_t_xgb, X_val_xgb = handleNaNs(X_train_t.copy(), X_val.copy(), option=2, thresh=0.7)

# %%
xgb.fit(X_train_xgb, y_train_xgb)
test_model_cross_val(xgb, y_train_xgb, X_train_xgb, k=5, verbose=True)
# Out:
# AVERAGE CV=5 ROC_AUC (TEST): 0.9303962772080832
# AVERAGE CV=5 STD (TEST): 0.04436666576440176

# %% [markdown]
# ## Importance Experiment XGB

# %%
optimiseImportance(xgb, X_train_xgb, y_train_xgb)
# Out:
# Cross validated importance experiment with k=5
# N:5
# N:10
# N:25
# N:50
# N:100
# N:200
# N:400
# N:800
# N:4870
#    Most important N descriptors  Average ROC_AUC  Standard Deviation
# 0                           5.0         0.913944            0.048971
# 1                          10.0         0.917866            0.049842
# 2                          25.0         0.934506            0.042544
# 3                          50.0         0.935908            0.045270
# 4                         100.0         0.938411            0.041870
# 5                         200.0         0.939359            0.041608
# 6                         400.0         0.937127            0.040621
# 7                         800.0         0.936838            0.040131
# 8                        4870.0         0.933064            0.041937

# %%
X_train_xgb, X_test_xgb, xgb = handle_importance(xgb, 
                                                X_train_xgb, 
                                                X_test_xgb, 
                                                threshold=-1, 
                                                n=100)

# Filted importance results
xgb.fit(X_train_xgb, y_train_xgb)
test_model_cross_val(xgb, y_train_xgb, X_train_xgb, k=5, verbose=True)
# Out:
# AVERAGE CV=5 ROC_AUC (TEST): 0.9384113490250252
# AVERAGE CV=5 STD (TEST): 0.04187013469977665

# %%
X_train_xgb
# Out:
#                                                   vapor.pressure.best.available  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                         1.390000e-02
# CC1=CCC(CC1)(O)C(C)C                                               4.270000e-02
# CC1=CC[C@](CC1)(O)C(C)C                                            4.270000e-02
# O=C1C2(C)CCC(C1(C)C)C2                                             8.170000e-01
# OCC1=CC[C@H](CC1)C(=C)C                                            4.780000e-03
# ...                                                                         ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                           7.320000e-06
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                         1.780000e-08
# C/C(=C\C)/C(=O)O                                                   1.330000e-01
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                   1.260000e-09
# C(COCCOCCO)O                                                       1.320000e-03
#
#                                                      Me  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                        0.985
# CC1=CCC(CC1)(O)C(C)C                              0.975
# CC1=CC[C@](CC1)(O)C(C)C                           0.975
# O=C1C2(C)CCC(C1(C)C)C2                            0.978
# OCC1=CC[C@H](CC1)C(=C)C                           0.978
# ...                                                 ...
# C1=CC(=CC=C1N)S(=O)(=O)N                          1.031
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C        0.975
# C/C(=C\C)/C(=O)O                                  1.013
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O  1.010
# C(COCCOCCO)O                                      1.021
#
#                                                   boiling.point.best.available  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                                              262.43
# CC1=CCC(CC1)(O)C(C)C                                                    209.00
# CC1=CC[C@](CC1)(O)C(C)C                                                 209.00
# O=C1C2(C)CCC(C1(C)C)C2                                                  193.00
# OCC1=CC[C@H](CC1)C(=C)C                                                 244.00
# ...                                                                        ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                                341.95
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C                              422.62
# C/C(=C\C)/C(=O)O                                                        185.00
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O                        434.53
# C(COCCOCCO)O                                                            285.00
#
#                                                   SpPosA_B.p.  Ho_Dz.v.  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                              1.228    19.045
# CC1=CCC(CC1)(O)C(C)C                                    1.210    13.468
# CC1=CC[C@](CC1)(O)C(C)C                                 1.210    13.468
# O=C1C2(C)CCC(C1(C)C)C2                                  1.258    12.652
# OCC1=CC[C@H](CC1)C(=C)C                                 1.228    13.206
# ...                                                       ...       ...
# C1=CC(=CC=C1N)S(=O)(=O)N                                1.244    12.033
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C              1.251    29.643
# C/C(=C\C)/C(=O)O                                        1.176     8.465
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O        1.161    39.512
# C(COCCOCCO)O                                            1.069    15.224
#
#                                                   SM1_Dz.v.  TDB01m    L2s  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                           -0.587   0.042  2.665
# CC1=CCC(CC1)(O)C(C)C                                 -0.336   0.046  1.425
# CC1=CC[C@](CC1)(O)C(C)C                              -0.336   0.046  1.425
# O=C1C2(C)CCC(C1(C)C)C2                               -0.336   0.057  2.020
# OCC1=CC[C@H](CC1)C(=C)C                              -0.336   0.052  1.097
# ...                                                     ...     ...    ...
# C1=CC(=CC=C1N)S(=O)(=O)N                             -0.824   0.181  1.315
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C           -0.445   0.027  1.726
# C/C(=C\C)/C(=O)O                                     -0.587   0.095  1.348
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O     -1.433   0.025  5.865
# C(COCCOCCO)O                                         -0.954   0.063  1.321
#
#                                                     E2e  AVS_B.s.  ...  \
# SMILES                                                             ...
# CCC(=O)OC1CC(CC=C1C)C(=C)C                        0.386     4.489  ...
# CC1=CCC(CC1)(O)C(C)C                              0.519     4.224  ...
# CC1=CC[C@](CC1)(O)C(C)C                           0.519     4.224  ...
# O=C1C2(C)CCC(C1(C)C)C2                            0.510     4.429  ...
# OCC1=CC[C@H](CC1)C(=C)C                           0.408     4.365  ...
# ...                                                 ...       ...  ...
# C1=CC(=CC=C1N)S(=O)(=O)N                          0.446     5.590  ...
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C        0.398     4.101  ...
# C/C(=C\C)/C(=O)O                                  0.521     5.260  ...
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O  0.312     4.877  ...
# C(COCCOCCO)O                                      0.476     4.647  ...
#
#                                                   GATS8v  MATS3e  RDF010s  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                         0.694  -0.088   15.740
# CC1=CCC(CC1)(O)C(C)C                               0.000  -0.102   17.853
# CC1=CC[C@](CC1)(O)C(C)C                            0.000  -0.102   17.853
# O=C1C2(C)CCC(C1(C)C)C2                             0.000   0.040   11.555
# OCC1=CC[C@H](CC1)C(=C)C                            0.478   0.013   16.997
# ...                                                  ...     ...      ...
# C1=CC(=CC=C1N)S(=O)(=O)N                           0.000  -0.247   19.261
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C         1.075   0.085   31.298
# C/C(=C\C)/C(=O)O                                   0.000  -0.034   11.567
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O   1.100  -0.021   28.203
# C(COCCOCCO)O                                       0.991   0.125   18.538
#
#                                                     IC5  Mor26u    R6s    P1s  \
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                        4.493   0.567  2.339  0.669
# CC1=CCC(CC1)(O)C(C)C                              3.883   0.479  1.238  0.709
# CC1=CC[C@](CC1)(O)C(C)C                           3.883   0.471  1.238  0.709
# O=C1C2(C)CCC(C1(C)C)C2                            3.708   0.358  0.828  0.459
# OCC1=CC[C@H](CC1)C(=C)C                           4.208   0.390  1.085  0.753
# ...                                                 ...     ...    ...    ...
# C1=CC(=CC=C1N)S(=O)(=O)N                          3.511  -0.308  2.324  0.786
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C        5.013   0.673  2.115  0.923
# C/C(=C\C)/C(=O)O                                  2.231   0.247  0.205  0.696
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O  4.635   0.824  3.578  0.604
# C(COCCOCCO)O                                      3.085   0.217  1.760  0.841
#
#                                                    JGI4  Mor22p  VE1_B.i.
# SMILES
# CCC(=O)OC1CC(CC=C1C)C(=C)C                        0.058   0.043     3.476
# CC1=CCC(CC1)(O)C(C)C                              0.082   0.132     3.111
# CC1=CC[C@](CC1)(O)C(C)C                           0.082   0.132     3.111
# O=C1C2(C)CCC(C1(C)C)C2                            0.067   0.103     2.981
# OCC1=CC[C@H](CC1)C(=C)C                           0.053  -0.075     3.135
# ...                                                 ...     ...       ...
# C1=CC(=CC=C1N)S(=O)(=O)N                          0.053  -0.122     3.058
# CCCCCCCCN[C@@H]([C@H](c1ccc(cc1)SC(C)C)O)C        0.035   0.417     3.306
# C/C(=C\C)/C(=O)O                                  0.000  -0.029     2.459
# C(CCC)OC(C(C(O)(C(=O)OCCCC)CC(=O)OCCCC)C(C)=O)=O  0.040   0.228     3.855
# C(COCCOCCO)O                                      0.013  -0.047     3.012
#
# [1894 rows x 100 columns]

# %% [markdown]
# ## Tuning paramaters

# %%
params = {
    'learning_rate': (0.01, 1.0),
    'n_estimators': (100, 1000),
    'max_depth': (3,10),
#    'subsample': (0.7, 1.0),  # Change for big datasets
    'colsample_bytree': (0.7, 1.0),  # Change for datasets with lots of features
    'gamma': (0, 5), 
    'scale_pos_weight': (1, 2.5)
    }

def xgboost_hyper_param(learning_rate,
                        n_estimators,
                        max_depth,
                        colsample_bytree,
                        gamma, 
                        scale_pos_weight):

    max_depth = int(max_depth)
    n_estimators = int(n_estimators)

    xgb_temp = XGBClassifier(
        max_depth=max_depth,
        colsample_bytree=colsample_bytree,
        learning_rate=learning_rate,
        n_estimators=n_estimators,
        gamma=gamma,
        scale_pos_weight=scale_pos_weight,
        seed=SEED)
    
    # calculate CV=5 K fold ROC_AUC accuracy for each model 

    return np.array(cross_val_score(xgb_temp, X_train_xgb, y_train_xgb, cv=3, scoring='roc_auc')).mean()

optimizer = BayesianOptimization(
            f=xgboost_hyper_param,
            pbounds=params,
            random_state=SEED)

optimizer.maximize(init_points=5, n_iter=50)
# Out:
# |   iter    |  target   | colsam... |   gamma   | learni... | max_depth | n_esti... | scale_... |
# -------------------------------------------------------------------------------------------------
# | 1         | 0.9303    | 0.8646    | 3.576     | 0.6067    | 6.814     | 481.3     | 1.969     |
# | 2         | 0.9248    | 0.8313    | 4.459     | 0.964     | 5.684     | 812.6     | 1.793     |
# | 3         | 0.9361    | 0.8704    | 4.628     | 0.08033   | 3.61      | 118.2     | 2.249     |
# | 4         | 0.9223    | 0.9334    | 4.35      | 0.9788    | 8.594     | 515.3     | 2.171     |
# | 5         | 0.9352    | 0.7355    | 3.2       | 0.1519    | 9.613     | 569.7     | 1.622     |
# | 6         | 0.9175    | 0.9324    | 3.685     | 0.8353    | 4.856     | 118.5     | 1.939     |
# | 7         | 0.9385    | 0.7767    | 2.654     | 0.1422    | 9.874     | 855.2     | 1.472     |
# | 8         | 0.9275    | 0.8818    | 0.06451   | 0.6193    | 5.891     | 992.5     | 1.636     |
# | 9         | 0.9404    | 0.7463    | 0.614     | 0.129     | 9.816     | 374.5     | 1.767     |
# | 10        | 0.9366    | 0.7496    | 0.9489    | 0.4696    | 9.269     | 522.9     | 1.286     |
# | 11        | 0.9365    | 0.7653    | 3.827     | 0.5729    | 7.477     | 156.4     | 1.487     |
# | 12        | 0.932     | 0.8971    | 0.6582    | 0.6401    | 8.454     | 327.2     | 1.363     |
# | 13        | 0.9086    | 0.9365    | 4.637     | 0.991     | 8.625     | 763.4     | 1.17      |
# | 44        | 0.93      | 0.9198    | 1.528     | 0.5534    | 5.12      | 658.4     | 1.063     |
# | 45        | 0.9358    | 0.8435    | 1.943     | 0.4941    | 9.262     | 855.1     | 1.438     |
# | 46        | 0.9384    | 0.8185    | 1.446     | 0.1975    | 9.018     | 280.5     | 1.34      |
# | 47        | 0.9287    | 0.9905    | 1.815     | 0.5851    | 8.412     | 281.3     | 2.118     |
# | 48        | 0.9304    | 0.7261    | 3.354     | 0.3885    | 8.749     | 840.4     | 2.28      |
# | 49        | 0.9383    | 0.7188    | 2.793     | 0.1323    | 8.447     | 841.9     | 1.959     |
# | 50        | 0.9316    | 0.8408    | 0.4609    | 0.4474    | 9.702     | 573.3     | 1.753     |
# | 51        | 0.9261    | 0.7172    | 1.829     | 0.5703    | 9.54      | 855.3     | 1.277     |
# | 52        | 0.9325    | 0.9343    | 4.225     | 0.3136    | 5.773     | 467.6     | 2.073     |
# | 53        | 0.9204    | 0.7903    | 3.637     | 0.8975    | 5.197     | 742.4     | 1.427     |
# | 54        | 0.9305    | 0.8749    | 2.613     | 0.6436    | 8.218     | 841.9     | 1.667     |
# | 55        | 0.931     | 0.8475    | 4.32      | 0.452     | 7.116     | 655.7     | 2.038     |
# =================================================================================================

# %%
params_tuned_xgb = optimizer.max['params']
params_tuned_xgb['max_depth'] = int(params_tuned_xgb['max_depth'])
params_tuned_xgb['n_estimators'] = int(params_tuned_xgb['n_estimators'])
print(params_tuned_xgb)

tuned_xgb = XGBClassifier(**params_tuned_xgb, seed=SEED)
tuned_xgb.fit(X_train_xgb, y_train_xgb)

test_model_cross_val(tuned_xgb, y_train_xgb, X_train_xgb, k=5, verbose=True)
# Out:
# {'colsample_bytree': 0.9455616778624734, 'gamma': 1.561744075279029, 'learning_rate': 0.059111859022187276, 'max_depth': 9, 'n_estimators': 280, 'scale_pos_weight': 1.9026517248188508}
# AVERAGE CV=5 ROC_AUC (TEST): 0.9406503373890865
# AVERAGE CV=5 STD (TEST): 0.040699066124903524

# %% [markdown]
# ### Final tuned paramaters

# %%
params = {'colsample_bytree': 0.8399023550780697, 'gamma': 0.338189317375458, 'learning_rate': 0.1742061546805264, 'max_depth': 8, 'n_estimators': 643, 'scale_pos_weight': 1.3398087284581912}
params=params_tuned_xgb
tuned_xgb = XGBClassifier(**params,
                          seed=SEED,  
                          n_jobs = -1)

# %%
tuned_xgb.fit(X_train_xgb, y_train_xgb)
test_model(tuned_xgb, y_test_xgb, X_test_xgb)
# Out:
# ROC_AUC (TEST): 0.97
#
#
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#        False       0.90      0.90      0.90        10
#         True       0.95      0.95      0.95        20
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30
# 0.97

# %% [markdown]
# # Keras

# %% [markdown]
# https://www.pluralsight.com/guides/classification-keras

# %%
# !pip install keras
# !pip install scikeras

import tensorflow as tf
import keras_tuner as kt
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical 
from scikeras.wrappers import KerasClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline


# for readibility 
y_train_nn = y_train.copy()
y_test_nn = y_test.copy()
X_train_nn = X_train.copy()
X_test_nn = X_test.copy()

tf.random.set_seed(SEED)
# Out:
# Requirement already satisfied: keras in /home/zoya/anaconda3/lib/python3.8/site-packages (2.11.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scikeras in /home/zoya/anaconda3/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /home/zoya/anaconda3/lib/python3.8/site-packages (from scikeras) (1.2.0)
# Requirement already satisfied: packaging>=0.21 in /home/zoya/anaconda3/lib/python3.8/site-packages (from scikeras) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/zoya/anaconda3/lib/python3.8/site-packages (from packaging>=0.21->scikeras) (2.4.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/zoya/anaconda3/lib/python3.8/site-packages (from scikit-learn>=1.0.0->scikeras) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/zoya/anaconda3/lib/python3.8/site-packages (from scikit-learn>=1.0.0->scikeras) (1.24.1)
# Requirement already satisfied: scipy>=1.3.2 in /home/zoya/anaconda3/lib/python3.8/site-packages (from scikit-learn>=1.0.0->scikeras) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/zoya/anaconda3/lib/python3.8/site-packages (from scikit-learn>=1.0.0->scikeras) (1.2.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1894 entries, CCC(=O)OC1CC(CC=C1C)C(=C)C to C(COCCOCCO)O
# Columns: 4870 entries, boiling.point.experimental to Infective.50
# dtypes: float64(2640), int64(2230)
# memory usage: 70.4+ MB

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Handle NaNs
# - You can't have missing values in a Neural Network, so we choose to remove all columns with them (for now)

# %%
X_train_nn, X_test_nn = handleNaNs(X_train.copy(), X_test.copy(), option=1)

# %% [markdown]
# ## Prepare a validation set
# - Stratified

# %%
X_train_t_nn, X_val_nn, y_train_t_nn, y_val_nn = X_train_t.copy(), X_val.copy(), y_train_t.copy(), y_val.copy()

# %%
X_train_t_nn, X_val_nn = handleNaNs(X_train_t_nn.copy(), X_val_nn.copy(), option=1)

# %% [markdown]
# ### Standardization
#
# Standardization is an effective data preparation scheme for tabular data when building neural network models. This is where the data is rescaled such that the mean value for each attribute is 0, and the standard deviation is 1. This preserves Gaussian and Gaussian-like distributions while normalizing the central tendencies for each attribute.
#
# https://machinelearningmastery.com/binary-classification-tutorial-with-the-keras-deep-learning-library/
#
# - not necessary for tree based algorithms because they are fairly insensitive to the scale of features "The decision tree splits a node on a feature that increases the homogeneity of the node. This split on a feature is not influenced by other features. Hence, there is virtually no effect of the remaining features on the split. This is what makes them invariant to the scale of the features." https://www.atoti.io/articles/when-to-perform-a-feature-scaling/#:~:text=In%20Neural%20Networks%20algorithm%20that,an%20essential%20pre%2Dprocessing%20step.
#
# - Note: The StandardScaler is only fit using the train_features to be sure the model is not peeking at the validation or test sets.

# %%
scaler = StandardScaler()
X_train_t_nn = scaler.fit_transform(X_train_t_nn) 
X_val_nn = scaler.transform(X_val_nn) 

scaler2 = StandardScaler()
X_train_nn = scaler2.fit_transform(X_train_nn) 
X_test_nn = scaler2.transform(X_test_nn)

# %% [markdown]
# ### Encode class values as integers

# %% [markdown]
# Use adam optimizer so we don't have to specify learning rate, as is the case with gradient descent, and optimise for it

# %%
encoder = LabelEncoder()
encoder.fit(y_train_nn)
y_train_nn = encoder.transform(y_train_nn)
y_train_t_nn = encoder.transform(y_train_t_nn)
y_test_nn = encoder.transform(y_test_nn)
y_val_nn = encoder.transform(y_val_nn)

# %% [markdown]
# ## Metrics

# %%
METRICS = [
  keras.metrics.TruePositives(name='tp'),
  keras.metrics.FalsePositives(name='fp'),
  keras.metrics.TrueNegatives(name='tn'),
  keras.metrics.FalseNegatives(name='fn'), 
  keras.metrics.Precision(name='precision'),
  keras.metrics.Recall(name='recall'),
  keras.metrics.AUC(name='auc', curve='ROC'),
]

# %% [markdown]
# ## Test model - Keras

# %%
def test_model_keras(model, history, X_val_nn, y_val_nn, X_train_nn, y_train_nn): 
    # Plot training and validation auc 

    plt.plot(history.history['auc'])
    plt.plot(history.history['val_auc'])
    plt.title('model roc_auc')
    plt.ylabel('ROC_AUC')
    plt.xlabel('epoch')
    plt.legend(['training', 'validation'], loc='upper left')
    plt.show()

    # Plot training and validation ROC curve

    y_pred_keras = model.predict(X_val_nn).ravel()
    fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_val_nn, y_pred_keras)
    auc_v_keras = metrics.roc_auc_score(y_val_nn, y_pred_keras)

    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr_keras, tpr_keras)

    y_pred_t_keras = model.predict(X_train_nn).ravel()
    fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_train_nn, y_pred_t_keras)
    auc_t_keras = metrics.roc_auc_score(y_train_nn, y_pred_t_keras)

    plt.plot(fpr_keras, tpr_keras)

    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(['', 'Validation (area = {:.3f})'.format(auc_v_keras), 'Training (area = {:.3f})'.format(auc_t_keras)], loc='best')
    plt.show()
    plt.show()

# %% [markdown]
# ## Baseline Single Layer model
# - Overfitting quite a bit, you can see it when you compare the validation set auc and the auc for the training set

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(X_train_nn.shape[-1]+1, activation="relu", input_shape=(X_train_nn.shape[-1],)))
model.add(Dense(1, activation='sigmoid'))

model.summary()

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=METRICS)

history = model.fit(X_train_t_nn, 
                      y_train_t_nn, 
                      epochs=30, 
                      validation_data=(X_val_nn, y_val_nn), 
                      verbose=0)

test_model_keras(model, history, X_val_nn, y_val_nn, X_train_t_nn, y_train_t_nn)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4867)              23687689
#
#  dense_1 (Dense)             (None, 1)                 4868
#
# =================================================================
# Total params: 23,692,557
# Trainable params: 23,692,557
# Non-trainable params: 0
# _________________________________________________________________
# 1/1 [==============================] - 0s 62ms/step
# 59/59 [==============================] - 1s 10ms/step

# %% [markdown]
# ## Feature selection on multilayer model

# %% [markdown]
# Using the set of the top 100 descriptors from RF and XGB, filter the dataset by these descriptors, and then measure validation accuracy

# %% [markdown]
# Choose f_classif method of feature selection, with 100 features.
# ### Tune and Train multilayer model

# %%
def model_builder_3(hp):

    model = keras.Sequential()
    model.add(Dense(100, input_shape=(100,), activation='relu'))

    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 2-length of layers
    hp_units = hp.Int('unit_1', min_value=2, max_value=2000, step=10)
    model.add(keras.layers.Dense(units=hp_units, activation='relu'))
    
    # dropout layer reduces overfitting
    hp_units = hp.Float('dropout_1', min_value=0.0, max_value=0.5, default=0.25, step=0.05)
    model.add(keras.layers.Dropout(hp_units))
    
    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 2-length of layers
    hp_units = hp.Int('unit_2', min_value=2, max_value=2000, step=10)
    model.add(keras.layers.Dense(units=hp_units, activation='relu'))
    
    model.add(Dense(1, activation='sigmoid'))
    
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                  loss='binary_crossentropy',
                  metrics=METRICS)

    return model

# %%
import sklearn.feature_selection as fs
from sklearn.feature_selection import VarianceThreshold

constant_filter = VarianceThreshold(threshold=0)
constant_filter.fit(X_train_nn)
X_train_nn = constant_filter.transform(X_train_nn)
X_test_nn = constant_filter.transform(X_test_nn)
X_val_nn = constant_filter.transform(X_val_nn)
X_train_t_nn = constant_filter.transform(X_train_t_nn)


    
bk = fs.SelectKBest(fs.f_classif, k=100)
bk.fit(X_train_nn, y_train_nn)
X_train_nn = bk.transform(X_train_nn)

# %%
X_val_nn = bk.transform(X_val_nn)

# %%
X_test_nn = bk.transform(X_test_nn)

# %%
X_train_t_nn = bk.transform(X_train_t_nn)

# %%
print(X_val_nn.shape)
tuner = kt.Hyperband(model_builder_3,
                     objective=kt.Objective("val_auc", direction="max"),
                     max_epochs=10,
                     factor=3,
                     seed=SEED, 
                     directory="results_dir",
                     project_name="odor",
                     overwrite=True,)
                     
tuner.search(X_train_t_nn, 
             y_train_t_nn, 
             epochs=30,
             validation_data=(X_val_nn, y_val_nn),
             callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_loss")])
# Out:
# Trial 30 Complete [00h 00m 02s]
# val_auc: 0.9800000190734863
#
# Best val_auc So Far: 1.0
# Total elapsed time: 00h 01m 11s
# INFO:tensorflow:Oracle triggered exit

# %%
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
The hyperparameter search is complete. \n The optimal number of units in the first densely-connected
layer is {best_hps.get('unit_1')} \n The optimal number of units in the second densely-connected
layer is {best_hps.get('unit_2')} \n The optimal number of dropouts in the first densely-connected
layer is {best_hps.get('dropout_1')}.\n The optimal learning 
rate is  {best_hps.get('learning_rate')}
""")
# Out:
# The hyperparameter search is complete.
#  The optimal number of units in the first densely-connected
# layer is 522
#  The optimal number of units in the second densely-connected
# layer is 352
#  The optimal number of dropouts in the first densely-connected
# layer is 0.15000000000000002.
#  The optimal learning
# rate is  0.0001

# %%
model4 = tuner.hypermodel.build(best_hps)
model4.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 100)               10100
#
#  dense_5 (Dense)             (None, 522)               52722
#
#  dropout_1 (Dropout)         (None, 522)               0
#
#  dense_6 (Dense)             (None, 352)               184096
#
#  dense_7 (Dense)             (None, 1)                 353
#
# =================================================================
# Total params: 247,271
# Trainable params: 247,271
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model4.fit(X_train_t_nn, 
                      y_train_t_nn, 
                      epochs=30,
                      batch_size=64,
                      validation_data=(X_val_nn, y_val_nn), 
                      verbose=0)

test_model_keras(model4, history, X_val_nn, y_val_nn, X_train_nn, y_train_nn)
# Out:
# 1/1 [==============================] - 0s 44ms/step
# 60/60 [==============================] - 0s 1ms/step

# %%
model_final = tuner.hypermodel.build(best_hps)

# Build the final model with all the training data with the optimal hyperparameters 
history = model_final.fit(X_train_nn, 
                      y_train_nn, 
                      epochs=30,
                      batch_size=64,
                      validation_data=(X_val_nn, y_val_nn), 
                      verbose=0)

test_model_keras(model4, history, X_val_nn, y_val_nn, X_train_nn, y_train_nn)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 60/60 [==============================] - 0s 1ms/step

# %% [markdown]
# ## Evaluate model on test data

# %%
y_pred_t_keras = model_final.predict(X_test_nn).ravel()
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test_nn, y_pred_t_keras)
auc_t_keras = metrics.roc_auc_score(y_test_nn, y_pred_t_keras)
auc_t_keras

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras)
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(['', 'Test (area = {:.3f})'.format(auc_t_keras)], loc='best')
plt.show()
plt.show()
# Out:
# 1/1 [==============================] - 0s 42ms/step
